# %% [markdown]
# <a href="https://colab.research.google.com/github/majaszymajda/przetwarzanie_strumieni_danych/blob/main/przetwarzanieStrDanych4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.signal as scisig
import matplotlib.pyplot as plt


def korelacja(y):
  result = []
  for r in range(m):
    temp = 0
    for i in range(r, N-r):
      temp += y[i]*y[i-r]
    result.append(1/(N-r)*temp)
  return result


N = 500
m = 400

t = np.linspace(-5, 5, 500)
y1 = np.sin(np.pi*2*t)
y2 = scisig.square(np.pi*2*t)
y3 = scisig.sawtooth(2*np.pi*t)

result1 = korelacja(y1)
result2 = korelacja(y2)
result3 = korelacja(y3)

y11 = autocorrelate(y1,m)
y22 = autocorrelate(y2,m)
y33 = autocorrelate(y3,m)

fig, ax = plt.subplots(3,3,figsize=(20,10))
ax[0,0].plot(t, y1)
ax[0,1].plot(t, y2)
ax[0,2].plot(t, y3)

ax[1,0].plot(list(range(m)), result1)
ax[1,1].plot(list(range(m)), result2)
ax[1,2].plot(list(range(m)), result3)

ax[2,0].plot(list(range(m)), y11)
ax[2,1].plot(list(range(m)), y22)
ax[2,2].plot(list(range(m)), y33)
